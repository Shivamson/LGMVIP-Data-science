# %% [markdown]
# # LetsGrowMoreVIP - Data Science Internship

# %% [markdown]
# ## Beginner Level Task 2 - Stock Market Prediction And Forecasting Using Stacked LSTM
#
# ### by - shivam laxman sonawaane

# %% [markdown]
# 1) Importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# 2) Loading the Dataset

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
data = pd.read_csv(url)
data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
#first five rows of the dataset
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
#last five rows of the dataset
data.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %% [markdown]
# 3) Sorting the dataset according to the date

# %%
data['Date'] = pd.to_datetime(data['Date'])
df = data.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %% [markdown]
# 4) Index is not in order,Making it in order

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# 5) Plotting the graph of stocks at Close

# %%
plt.plot(df['Close'])

# %%
df1 = df['Close']

# %% [markdown]
# 6) Feature Scaling

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# 7) Splitting the data into training and test sets

# %%
training_size = int(len(df1)*0.70)
test_size = len(df1) - training_size


train_data = df1[0:training_size,:]
test_data = df1[training_size:len(df1), :1]
training_size, test_size
# Out:
# (1424, 611)

# %% [markdown]
# 8) convert an array of values into a dataset matrix

# %%
def datasetCrtd(dataset, time_step=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    dataY.append(dataset[i + time_step, 0])

  return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = datasetCrtd(train_data, time_step)
X_test, ytest = datasetCrtd(test_data, time_step)
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %% [markdown]
# 9)Reshape input which is required for LSTM

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# 10) building the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 7s 180ms/step - loss: 0.0087 - val_loss: 0.0017
# Epoch 2/60
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 3/60
# 19/19 [==============================] - 2s 108ms/step - loss: 9.1717e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 2s 115ms/step - loss: 8.4118e-04 - val_loss: 0.0012
# Epoch 5/60
# 19/19 [==============================] - 2s 111ms/step - loss: 8.3032e-04 - val_loss: 0.0012
# Epoch 6/60
# 19/19 [==============================] - 2s 112ms/step - loss: 7.8949e-04 - val_loss: 0.0011
# Epoch 7/60
# 19/19 [==============================] - 2s 106ms/step - loss: 7.8347e-04 - val_loss: 9.9055e-04
# Epoch 8/60
# 19/19 [==============================] - 2s 107ms/step - loss: 7.4361e-04 - val_loss: 9.6970e-04
# Epoch 9/60
# 19/19 [==============================] - 2s 106ms/step - loss: 7.1919e-04 - val_loss: 9.8408e-04
# Epoch 10/60
# 19/19 [==============================] - 2s 109ms/step - loss: 7.0351e-04 - val_loss: 8.7391e-04
# Epoch 11/60
# 19/19 [==============================] - 2s 108ms/step - loss: 6.7368e-04 - val_loss: 8.6491e-04
# Epoch 12/60
# 19/19 [==============================] - 2s 106ms/step - loss: 6.7506e-04 - val_loss: 8.8001e-04
# Epoch 13/60
# 19/19 [==============================] - 2s 110ms/step - loss: 6.8893e-04 - val_loss: 7.5784e-04
# Epoch 14/60
# 19/19 [==============================] - 2s 114ms/step - loss: 6.3680e-04 - val_loss: 7.3393e-04
# Epoch 15/60
# 19/19 [==============================] - 2s 113ms/step - loss: 6.1447e-04 - val_loss: 7.1813e-04
# Epoch 16/60
# 19/19 [==============================] - 2s 110ms/step - loss: 6.3615e-04 - val_loss: 6.9313e-04
# Epoch 17/60
# 19/19 [==============================] - 2s 116ms/step - loss: 5.7210e-04 - val_loss: 6.7070e-04
# Epoch 18/60
# 19/19 [==============================] - 2s 111ms/step - loss: 5.6405e-04 - val_loss: 6.2290e-04
# Epoch 19/60
# 19/19 [==============================] - 2s 111ms/step - loss: 5.5415e-04 - val_loss: 6.4247e-04
# Epoch 20/60
# 19/19 [==============================] - 2s 126ms/step - loss: 5.5019e-04 - val_loss: 6.7040e-04
# Epoch 21/60
# 19/19 [==============================] - 2s 109ms/step - loss: 5.2893e-04 - val_loss: 5.7174e-04
# Epoch 22/60
# 19/19 [==============================] - 2s 110ms/step - loss: 5.3287e-04 - val_loss: 6.0481e-04
# Epoch 23/60
# 19/19 [==============================] - 2s 110ms/step - loss: 4.9047e-04 - val_loss: 5.7770e-04
# Epoch 24/60
# 19/19 [==============================] - 2s 107ms/step - loss: 5.0751e-04 - val_loss: 5.2925e-04
# Epoch 25/60
# 19/19 [==============================] - 2s 113ms/step - loss: 5.6843e-04 - val_loss: 7.3212e-04
# Epoch 26/60
# 19/19 [==============================] - 2s 116ms/step - loss: 5.3851e-04 - val_loss: 5.3344e-04
# Epoch 27/60
# 19/19 [==============================] - 2s 110ms/step - loss: 4.9857e-04 - val_loss: 4.9003e-04
# Epoch 28/60
# 19/19 [==============================] - 2s 109ms/step - loss: 4.5126e-04 - val_loss: 4.7014e-04
# Epoch 29/60
# 19/19 [==============================] - 2s 107ms/step - loss: 4.4601e-04 - val_loss: 4.6884e-04
# Epoch 30/60
# 19/19 [==============================] - 2s 107ms/step - loss: 4.2762e-04 - val_loss: 4.6837e-04
# Epoch 31/60
# 19/19 [==============================] - 2s 123ms/step - loss: 4.2538e-04 - val_loss: 4.6973e-04
# Epoch 32/60
# 19/19 [==============================] - 2s 106ms/step - loss: 4.2049e-04 - val_loss: 4.2339e-04
# Epoch 33/60
# 19/19 [==============================] - 2s 117ms/step - loss: 3.9561e-04 - val_loss: 4.1302e-04
# Epoch 34/60
# 19/19 [==============================] - 2s 113ms/step - loss: 3.8649e-04 - val_loss: 3.9668e-04
# Epoch 35/60
# 19/19 [==============================] - 2s 109ms/step - loss: 3.7461e-04 - val_loss: 4.2360e-04
# Epoch 36/60
# 19/19 [==============================] - 2s 114ms/step - loss: 3.7900e-04 - val_loss: 4.0052e-04
# Epoch 37/60
# 19/19 [==============================] - 2s 109ms/step - loss: 3.6743e-04 - val_loss: 3.6181e-04
# Epoch 38/60
# 19/19 [==============================] - 2s 108ms/step - loss: 3.5514e-04 - val_loss: 3.5951e-04
# Epoch 39/60
# 19/19 [==============================] - 2s 108ms/step - loss: 3.5968e-04 - val_loss: 3.2241e-04
# Epoch 40/60
# 19/19 [==============================] - 2s 106ms/step - loss: 3.4825e-04 - val_loss: 3.7609e-04
# Epoch 41/60
# 19/19 [==============================] - 2s 109ms/step - loss: 3.5809e-04 - val_loss: 3.9998e-04
# Epoch 42/60
# 19/19 [==============================] - 2s 118ms/step - loss: 3.5720e-04 - val_loss: 2.9791e-04
# Epoch 43/60
# 19/19 [==============================] - 2s 112ms/step - loss: 3.1522e-04 - val_loss: 3.0585e-04
# Epoch 44/60
# 19/19 [==============================] - 2s 107ms/step - loss: 3.0138e-04 - val_loss: 2.7913e-04
# Epoch 45/60
# 19/19 [==============================] - 2s 110ms/step - loss: 3.4505e-04 - val_loss: 3.8830e-04
# Epoch 46/60
# 19/19 [==============================] - 2s 110ms/step - loss: 3.3946e-04 - val_loss: 3.4610e-04
# Epoch 47/60
# 19/19 [==============================] - 2s 114ms/step - loss: 3.1707e-04 - val_loss: 2.7004e-04
# Epoch 48/60
# 19/19 [==============================] - 2s 112ms/step - loss: 2.8894e-04 - val_loss: 3.0451e-04
# Epoch 49/60
# 19/19 [==============================] - 2s 112ms/step - loss: 3.0804e-04 - val_loss: 2.5484e-04
# Epoch 50/60
# 19/19 [==============================] - 2s 117ms/step - loss: 2.7174e-04 - val_loss: 2.4403e-04
# Epoch 51/60
# 19/19 [==============================] - 2s 105ms/step - loss: 2.6608e-04 - val_loss: 2.7916e-04
# Epoch 52/60
# 19/19 [==============================] - 2s 108ms/step - loss: 2.6125e-04 - val_loss: 2.2005e-04
# Epoch 53/60
# 19/19 [==============================] - 2s 121ms/step - loss: 2.7112e-04 - val_loss: 2.2360e-04
# Epoch 54/60
# 19/19 [==============================] - 2s 106ms/step - loss: 2.7708e-04 - val_loss: 2.2272e-04
# Epoch 55/60
# 19/19 [==============================] - 2s 110ms/step - loss: 2.5053e-04 - val_loss: 2.0983e-04
# Epoch 56/60
# 19/19 [==============================] - 2s 104ms/step - loss: 2.3633e-04 - val_loss: 2.5140e-04
# Epoch 57/60
# 19/19 [==============================] - 2s 106ms/step - loss: 2.3647e-04 - val_loss: 2.3215e-04
# Epoch 58/60
# 19/19 [==============================] - 2s 122ms/step - loss: 2.3935e-04 - val_loss: 2.0210e-04
# Epoch 59/60
# 19/19 [==============================] - 2s 113ms/step - loss: 2.3174e-04 - val_loss: 1.9958e-04
# Epoch 60/60
# 19/19 [==============================] - 2s 121ms/step - loss: 2.2137e-04 - val_loss: 2.2505e-04

# %% [markdown]
# 10) Prediction of scaled test set

# %%
test_predict = model.predict(X_test)

# %% [markdown]
# 11) transform to original test set

# %%
test_predict1 = scaler.inverse_transform(test_predict)
test_predict1
# Out:
# array([[143.43193 ],
#        [143.70628 ],
#        [143.02399 ],
#        [140.70056 ],
#        [138.86038 ],
#        [137.93857 ],
#        [138.6357  ],
#        [140.05293 ],
#        [140.7686  ],
#        [140.76987 ],
#        [140.64592 ],
#        [141.56148 ],
#        [142.3137  ],
#        [143.7457  ],
#        [145.82542 ],
#        [144.59306 ],
#        [142.43979 ],
#        [141.59492 ],
#        [141.75021 ],
#        [145.82977 ],
#        [150.2857  ],
#        [153.21642 ],
#        [154.31354 ],
#        [152.81883 ],
#        [152.19118 ],
#        [151.58533 ],
#        [151.65901 ],
#        [153.05215 ],
#        [153.99744 ],
#        [154.32278 ],
#        [154.78716 ],
#        [153.91019 ],
#        [151.0485  ],
#        [145.77225 ],
#        [141.86563 ],
#        [140.13554 ],
#        [139.8775  ],
#        [139.30449 ],
#        [137.55003 ],
#        [134.39838 ],
#        [131.75757 ],
#        [130.1276  ],
#        [128.00807 ],
#        [126.88538 ],
#        [124.99796 ],
#        [122.569565],
#        [121.478386],
#        [120.89006 ],
#        [120.9005  ],
#        [120.157   ],
#        [119.357574],
#        [118.84865 ],
#        [118.05237 ],
#        [117.940475],
#        [118.876236],
#        [120.42014 ],
#        [122.292946],
#        [123.38464 ],
#        [123.542625],
#        [123.63388 ],
#        [123.72535 ],
#        [123.548386],
#        [123.62312 ],
#        [123.9168  ],
#        [124.14447 ],
#        [124.271324],
#        [124.192314],
#        [124.444305],
#        [124.861725],
#        [125.255066],
#        [124.78514 ],
#        [123.96955 ],
#        [122.73254 ],
#        [121.45671 ],
#        [120.10474 ],
#        [119.85495 ],
#        [120.18489 ],
#        [121.01803 ],
#        [122.11163 ],
#        [123.3998  ],
#        [124.66558 ],
#        [125.55431 ],
#        [126.12859 ],
#        [126.24409 ],
#        [126.07934 ],
#        [125.75486 ],
#        [126.21067 ],
#        [126.50323 ],
#        [127.32376 ],
#        [128.14565 ],
#        [128.69278 ],
#        [129.19868 ],
#        [130.0662  ],
#        [129.9019  ],
#        [129.46468 ],
#        [129.25014 ],
#        [129.25711 ],
#        [129.6068  ],
#        [130.39162 ],
#        [130.80086 ],
#        [131.13545 ],
#        [133.37381 ],
#        [137.42226 ],
#        [141.55042 ],
#        [143.96068 ],
#        [145.832   ],
#        [146.28444 ],
#        [145.7552  ],
#        [144.34306 ],
#        [142.76082 ],
#        [141.00743 ],
#        [140.20386 ],
#        [140.34447 ],
#        [141.42053 ],
#        [142.70021 ],
#        [143.16785 ],
#        [142.75783 ],
#        [141.91533 ],
#        [140.89311 ],
#        [141.72624 ],
#        [142.70256 ],
#        [143.90501 ],
#        [144.8103  ],
#        [145.0485  ],
#        [144.4018  ],
#        [143.29503 ],
#        [141.24617 ],
#        [140.03876 ],
#        [140.2427  ],
#        [142.30142 ],
#        [144.77507 ],
#        [147.04247 ],
#        [148.23999 ],
#        [147.5182  ],
#        [148.59525 ],
#        [150.46826 ],
#        [151.16084 ],
#        [151.4446  ],
#        [151.54417 ],
#        [151.41258 ],
#        [151.36409 ],
#        [151.8849  ],
#        [152.84709 ],
#        [153.85513 ],
#        [153.71466 ],
#        [153.08182 ],
#        [153.32872 ],
#        [153.52026 ],
#        [153.11513 ],
#        [152.17647 ],
#        [150.90233 ],
#        [150.60693 ],
#        [151.67096 ],
#        [152.80367 ],
#        [153.66205 ],
#        [153.96112 ],
#        [154.50954 ],
#        [154.4852  ],
#        [154.40477 ],
#        [155.90842 ],
#        [157.30382 ],
#        [157.66914 ],
#        [156.26463 ],
#        [154.55077 ],
#        [153.95044 ],
#        [154.53313 ],
#        [155.23573 ],
#        [155.22379 ],
#        [155.4807  ],
#        [155.8386  ],
#        [155.55145 ],
#        [153.17386 ],
#        [151.16501 ],
#        [149.72478 ],
#        [148.09378 ],
#        [145.90773 ],
#        [144.60007 ],
#        [145.49945 ],
#        [146.86252 ],
#        [147.85509 ],
#        [149.43074 ],
#        [151.7941  ],
#        [154.51897 ],
#        [156.4048  ],
#        [156.3477  ],
#        [156.0298  ],
#        [155.5083  ],
#        [154.99905 ],
#        [153.95334 ],
#        [154.50038 ],
#        [156.60843 ],
#        [159.02695 ],
#        [160.34438 ],
#        [159.9061  ],
#        [158.88596 ],
#        [158.0587  ],
#        [156.9925  ],
#        [154.94684 ],
#        [151.87799 ],
#        [150.07344 ],
#        [149.55443 ],
#        [150.56912 ],
#        [152.34714 ],
#        [153.30075 ],
#        [155.34871 ],
#        [156.42569 ],
#        [157.82957 ],
#        [162.00995 ],
#        [167.31795 ],
#        [172.52489 ],
#        [176.07216 ],
#        [176.63509 ],
#        [176.40492 ],
#        [174.7507  ],
#        [173.65573 ],
#        [172.05888 ],
#        [171.36331 ],
#        [170.86345 ],
#        [171.26562 ],
#        [172.57368 ],
#        [172.38696 ],
#        [171.72383 ],
#        [171.3704  ],
#        [170.54366 ],
#        [168.79874 ],
#        [167.85986 ],
#        [167.71944 ],
#        [169.50154 ],
#        [169.8411  ],
#        [167.53665 ],
#        [162.52797 ],
#        [161.23486 ],
#        [168.17581 ],
#        [182.90402 ],
#        [194.18945 ],
#        [199.20654 ],
#        [199.08098 ],
#        [193.4069  ],
#        [190.5351  ],
#        [189.8861  ],
#        [190.26015 ],
#        [189.9071  ],
#        [192.72627 ],
#        [196.71672 ],
#        [199.18044 ],
#        [197.67902 ],
#        [196.53552 ],
#        [200.67108 ],
#        [205.33629 ],
#        [207.9985  ],
#        [209.27394 ],
#        [210.53123 ],
#        [208.74052 ],
#        [208.58096 ],
#        [208.83762 ],
#        [210.48033 ],
#        [213.49934 ],
#        [214.36475 ],
#        [212.90964 ],
#        [205.81676 ],
#        [197.8436  ],
#        [198.03984 ],
#        [199.56139 ],
#        [202.78143 ],
#        [206.57611 ],
#        [208.8491  ],
#        [208.16663 ],
#        [208.29227 ],
#        [208.72713 ],
#        [208.14241 ],
#        [207.28568 ],
#        [207.25685 ],
#        [208.98059 ],
#        [209.82133 ],
#        [209.40263 ],
#        [209.05045 ],
#        [207.32733 ],
#        [204.81226 ],
#        [202.70155 ],
#        [205.23273 ],
#        [206.74683 ],
#        [208.87173 ],
#        [215.51883 ],
#        [223.90118 ],
#        [228.07664 ],
#        [227.74634 ],
#        [224.49858 ],
#        [221.13864 ],
#        [224.72006 ],
#        [224.76083 ],
#        [222.7344  ],
#        [229.87657 ],
#        [235.38135 ],
#        [235.43277 ],
#        [239.55557 ],
#        [245.57307 ],
#        [248.90208 ],
#        [252.99673 ],
#        [263.13226 ],
#        [268.31244 ],
#        [267.86664 ],
#        [265.79074 ],
#        [266.88702 ],
#        [268.29138 ],
#        [275.18146 ],
#        [275.99045 ],
#        [277.80673 ],
#        [277.33997 ],
#        [273.73706 ],
#        [272.1904  ],
#        [270.13266 ],
#        [274.7883  ],
#        [281.9879  ],
#        [290.76987 ],
#        [287.78467 ],
#        [279.52567 ],
#        [274.8667  ],
#        [276.57306 ],
#        [282.22363 ],
#        [291.3878  ],
#        [295.71344 ],
#        [294.27094 ],
#        [292.81332 ],
#        [294.1378  ],
#        [295.35358 ],
#        [296.37924 ],
#        [302.61594 ],
#        [304.6488  ],
#        [302.48877 ],
#        [300.553   ],
#        [300.9979  ],
#        [302.71924 ],
#        [306.67853 ],
#        [307.5204  ],
#        [305.8705  ],
#        [304.12305 ],
#        [311.00558 ],
#        [314.67096 ],
#        [310.2981  ],
#        [304.46216 ],
#        [297.769   ],
#        [297.61246 ],
#        [300.88156 ],
#        [302.28442 ],
#        [300.25064 ],
#        [298.26657 ],
#        [296.12054 ],
#        [296.49496 ],
#        [289.5678  ],
#        [283.1422  ],
#        [273.78333 ],
#        [268.88876 ],
#        [265.85718 ],
#        [273.48715 ],
#        [280.4141  ],
#        [280.1423  ],
#        [280.2694  ],
#        [278.0064  ],
#        [273.7554  ],
#        [269.27188 ],
#        [263.32114 ],
#        [258.07953 ],
#        [259.3223  ],
#        [260.3038  ],
#        [265.3509  ],
#        [270.42392 ],
#        [272.45398 ],
#        [271.59482 ],
#        [269.2754  ],
#        [268.07025 ],
#        [267.21887 ],
#        [264.12213 ],
#        [265.0045  ],
#        [264.49207 ],
#        [268.2043  ],
#        [272.70837 ],
#        [274.4593  ],
#        [274.30432 ],
#        [269.1778  ],
#        [258.5034  ],
#        [253.88298 ],
#        [256.25662 ],
#        [257.77792 ],
#        [257.4771  ],
#        [259.17117 ],
#        [261.39023 ],
#        [259.04163 ],
#        [266.1041  ],
#        [271.25095 ],
#        [268.6405  ],
#        [265.75772 ],
#        [264.60828 ],
#        [267.85583 ],
#        [269.62552 ],
#        [268.68985 ],
#        [267.53143 ],
#        [268.27765 ],
#        [271.873   ],
#        [275.0553  ],
#        [277.65335 ],
#        [279.41595 ],
#        [279.56165 ],
#        [277.28503 ],
#        [275.36917 ],
#        [278.63104 ],
#        [283.23016 ],
#        [285.71466 ],
#        [288.80423 ],
#        [287.21942 ],
#        [281.1133  ],
#        [278.3399  ],
#        [283.0256  ],
#        [285.07483 ],
#        [285.9642  ],
#        [282.06216 ],
#        [280.20425 ],
#        [262.0668  ],
#        [242.06139 ],
#        [235.28824 ],
#        [242.88493 ],
#        [250.20802 ],
#        [251.58932 ],
#        [250.94008 ],
#        [250.68356 ],
#        [252.04103 ],
#        [254.10876 ],
#        [255.90222 ],
#        [254.0756  ],
#        [255.38715 ],
#        [259.91806 ],
#        [259.36975 ],
#        [252.35245 ],
#        [252.38425 ],
#        [257.25168 ],
#        [261.83475 ],
#        [263.3354  ],
#        [260.79962 ],
#        [260.49695 ],
#        [262.66962 ],
#        [269.0788  ],
#        [269.81497 ],
#        [269.2304  ],
#        [263.92075 ],
#        [256.5979  ],
#        [252.24634 ],
#        [254.8118  ],
#        [260.38773 ],
#        [265.21323 ],
#        [265.399   ],
#        [262.19012 ],
#        [262.4531  ],
#        [261.06168 ],
#        [268.95557 ],
#        [273.57526 ],
#        [269.64444 ],
#        [261.87857 ],
#        [263.13922 ],
#        [267.44098 ],
#        [267.19836 ],
#        [262.73605 ],
#        [256.21014 ],
#        [244.49033 ],
#        [241.2777  ],
#        [239.33878 ],
#        [236.05312 ],
#        [237.4478  ],
#        [242.65881 ],
#        [247.4287  ],
#        [243.15138 ],
#        [237.88507 ],
#        [236.97827 ],
#        [238.19589 ],
#        [241.79817 ],
#        [238.00185 ],
#        [232.85736 ],
#        [230.23439 ],
#        [233.10023 ],
#        [235.78389 ],
#        [235.93082 ],
#        [235.38628 ],
#        [232.87741 ],
#        [231.42467 ],
#        [233.02922 ],
#        [236.01768 ],
#        [239.66786 ],
#        [242.46051 ],
#        [240.45352 ],
#        [234.53447 ],
#        [228.216   ],
#        [229.13991 ],
#        [231.18588 ],
#        [233.08192 ],
#        [234.74483 ],
#        [234.4054  ],
#        [234.48126 ],
#        [227.68123 ],
#        [220.91238 ],
#        [217.90353 ],
#        [219.521   ],
#        [221.90283 ],
#        [220.06445 ],
#        [220.62013 ],
#        [227.94559 ],
#        [235.32594 ],
#        [236.83035 ],
#        [234.0986  ],
#        [230.70917 ],
#        [228.29936 ],
#        [229.34775 ],
#        [230.63278 ]], dtype=float32)

# %% [markdown]
# 12) Performance Metrics

# %%
import math
from sklearn.metrics import mean_squared_error
import sklearn.metrics as metrics
math.sqrt(mean_squared_error(ytest, test_predict))
# Out:
# 0.026039706657280465

# %% [markdown]
# # MSE Is low
